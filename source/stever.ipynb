# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
a = [1, 2, 3, 4, 5]
ps = [1/16, 1/8, 5/8, 1/8, 1/16]

# %%
sum(a)/len(a)
# Out:
# 3.0

# %%
plt.plot(a)

# %%
plt.plot(ps)

# %%
plt.hist(ps)
# Out:
# (array([2., 2., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([0.0625 , 0.11875, 0.175  , 0.23125, 0.2875 , 0.34375, 0.4    ,
#         0.45625, 0.5125 , 0.56875, 0.625  ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(ps, cumulative = True)
plt.title('Cumulative Distribution')
# Out:
# Text(0.5,1,'Cumulative Distribution')

# %% [markdown]
# ## Distributions
#
# Here are some.

# %%
plt.bar(a, ps)
# Out:
# <Container object of 5 artists>

# %%
plt.hist?

# %%
plt.hist(a, cumulative = True)
# Out:
# (array([1., 1., 2., 2., 2., 3., 3., 4., 4., 5.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(ps)
# Out:
# (array([2., 2., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([0.0625 , 0.11875, 0.175  , 0.23125, 0.2875 , 0.34375, 0.4    ,
#         0.45625, 0.5125 , 0.56875, 0.625  ]),
#  <a list of 10 Patch objects>)
